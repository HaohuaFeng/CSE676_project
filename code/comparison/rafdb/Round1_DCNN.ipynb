# %% [markdown]
# # Round 1

# %% [markdown]
# # model: DCNN (version 0, 0+, 1, 2, 3, 3+, 4, 5, 6, 7)
# ## we select the winner from them.

# %%
# Training Loss

import matplotlib.pyplot as plt
import sys

sys.path.append("../../")  # Add the parent directory to the Python path
import helper.utility as utility

# Model list
model_configs = [
    "v0+_Adam_[RAF(aug12)]",
    "v0_Adam_[FER(aug)]",
    "v0_Adam_[RAF(aug12)]",
    "v1_Adam_[RAF(aug12)]",
    "v2_Adam_[RAF(aug12)]",
    "v3+_Adam_[RAF(aug12)]",
    "v3_Adam_[RAF(aug12)]",
    "v4_Adam_[RAF(aug12)]",
    "v5_Adam_[RAF(aug12)]",
    "v6_Adam_[RAF(aug12)]",
    "v7_Adam_[RAF(aug12)]",
]
# Define different colors for the lines
colors = ["b", "g", "r", "c", "m", "y", "k", "#FFD700", "#33FF57", "#5733FF", "#FF5733"]
plt.figure(figsize=(15, 9))

for i, model_name in enumerate(model_configs):
    identifier = model_name

    # load and plot the loss history
    record_save_path = "../../model_data/DCNN/" + identifier
    data = utility.read_pickle_files(record_save_path + "/loss_history.pkl")
    plt.plot(
        range(1, len(data) + 1),
        data,
        label=identifier,
        color=colors[i],
    )

plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("Training Loss")
plt.legend()
plt.savefig("../../model_data/DCNN/Round1/all_loss_history.png")
plt.show()

# %%
# Training Accuracy

import matplotlib.pyplot as plt
import sys

sys.path.append("../../")  # Add the parent directory to the Python path
import helper.utility as utility

# Model list
model_configs = [
    "v0+_Adam_[RAF(aug12)]",
    "v0_Adam_[FER(aug)]",
    "v0_Adam_[RAF(aug12)]",
    "v1_Adam_[RAF(aug12)]",
    "v2_Adam_[RAF(aug12)]",
    "v3+_Adam_[RAF(aug12)]",
    "v3_Adam_[RAF(aug12)]",
    "v4_Adam_[RAF(aug12)]",
    "v5_Adam_[RAF(aug12)]",
    "v6_Adam_[RAF(aug12)]",
    "v7_Adam_[RAF(aug12)]",
]
# Define different colors for the lines
colors = ["b", "g", "r", "c", "m", "y", "k", "#FFD700", "#33FF57", "#5733FF", "#FF5733"]
plt.figure(figsize=(15, 9))


for i, model_name in enumerate(model_configs):
    identifier = model_name

    # load and plot the loss history
    record_save_path = "../../model_data/DCNN/" + identifier
    data = utility.read_pickle_files(record_save_path + "/accuracy_history.pkl")
    plt.plot(
        range(1, len(data) + 1),
        data,
        label=identifier,
        color=colors[i],
    )

plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.title("Training Accuracy")
plt.legend()
plt.savefig("../../model_data/DCNN/Round1/all_training_accuracy.png")
plt.show()

# %%
# Validation Loss

import matplotlib.pyplot as plt
import sys

sys.path.append("../../")  # Add the parent directory to the Python path
import helper.utility as utility

# Model list
model_configs = [
    "v0+_Adam_[RAF(aug12)]",
    "v0_Adam_[FER(aug)]",
    "v0_Adam_[RAF(aug12)]",
    "v1_Adam_[RAF(aug12)]",
    "v2_Adam_[RAF(aug12)]",
    "v3+_Adam_[RAF(aug12)]",
    "v3_Adam_[RAF(aug12)]",
    "v4_Adam_[RAF(aug12)]",
    "v5_Adam_[RAF(aug12)]",
    "v6_Adam_[RAF(aug12)]",
    "v7_Adam_[RAF(aug12)]",
]
# Define different colors for the lines
colors = ["b", "g", "r", "c", "m", "y", "k", "#FFD700", "#33FF57", "#5733FF", "#FF5733"]
plt.figure(figsize=(15, 9))

for i, model_name in enumerate(model_configs):
    identifier = model_name

    # load and plot the loss history
    record_save_path = "../../model_data/DCNN/" + identifier
    data = utility.read_pickle_files(record_save_path + "/val_loss_history.pkl")
    plt.plot(
        range(1, len(data) + 1),
        data,
        label=identifier,
        color=colors[i],
    )

plt.xlabel("epoch")
plt.ylabel("validation loss")
plt.title("Validation Loss")
plt.legend()
plt.savefig("../../model_data/DCNN/Round1/all_validation_loss.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import sys

sys.path.append("../../")  # Add the parent directory to the Python path
import helper.utility as utility

# Model list
model_configs = [
    "v0+_Adam_[RAF(aug12)]",
    "v0_Adam_[FER(aug)]",
    "v0_Adam_[RAF(aug12)]",
    "v1_Adam_[RAF(aug12)]",
    "v2_Adam_[RAF(aug12)]",
    "v3+_Adam_[RAF(aug12)]",
    "v3_Adam_[RAF(aug12)]",
    "v4_Adam_[RAF(aug12)]",
    "v5_Adam_[RAF(aug12)]",
    "v6_Adam_[RAF(aug12)]",
    "v7_Adam_[RAF(aug12)]",
]
# Define different colors for the lines
colors = ["b", "g", "r", "c", "m", "y", "k", "#FFD700", "#33FF57", "#5733FF", "#FF5733"]
plt.figure(figsize=(15, 9))

for i, model_name in enumerate(model_configs):
    identifier = model_name

    # load and plot the loss history
    record_save_path = "../../model_data/DCNN/" + identifier
    data = utility.read_pickle_files(record_save_path + "/val_accuracy_history.pkl")

    # Find the maximum accuracy and its corresponding epoch
    max_accuracy = max(data)
    max_epoch = data.index(max_accuracy) + 1  # Adding 1 because epochs start from 1

    # Plotting the data
    plt.plot(
        range(1, len(data) + 1),
        data,
        label=identifier,
        color=colors[i],
    )

    # Annotating the maximum point
    plt.annotate(
        f"({max_epoch}, {max_accuracy:.3f})",
        xy=(max_epoch, max_accuracy),
        xytext=(5, 5),  # Slight offset for text
        textcoords="offset points",
        arrowprops=dict(arrowstyle="->", lw=1),
        ha="center",
    )

plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.title("Validation Accuracy")
plt.legend()
plt.savefig("../../model_data/DCNN/Round1/all_validation_accuracy.png")
plt.show()

# %% [markdown]
# # The winner of Round 1 is `v5_Adam_[RAF(aug12)]`, and the accuracy is 0.797. (see the confusion matrix graph in report)
