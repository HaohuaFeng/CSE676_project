# %% [markdown]
# # Round 3

# %% [markdown]
# # model: Customized-cnn_ELU + Optimizer (SGD, Adma_amsgrad)
# ## we select the winner from them.

# %%
# Training Loss

import matplotlib.pyplot as plt
import sys

sys.path.append("../")  # Add the parent directory to the Python path
import helper.utility as utility

# Model list
model_configs = ["Customized-cnn_ELU_"]
# optimizer list
optimizer_configs = ["SGD", "Adam_amsgrad"]
# Define different colors for the lines
colors = ["b", "g"]
plt.figure(figsize=(10, 6))

for i, model_name in enumerate(model_configs):
    for j, optimizer_name in enumerate(optimizer_configs):
        identifier = model_name + optimizer_name

        # load and plot the loss history
        record_save_path = "../../model_data/" + identifier
        data = utility.read_pickle_files(record_save_path + "/loss_history.pkl")
        color_index = (i * len(optimizer_configs) + j) % len(colors)
        plt.plot(
            range(1, len(data) + 1),
            data,
            label=identifier,
            color=colors[color_index],
        )

plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("Training Loss")
plt.legend()
plt.savefig("../../model_data/Round3/Customized-cnn_ELU_all_loss_history.png")
plt.show()

# %%
# Training Accuracy

import matplotlib.pyplot as plt
import sys

sys.path.append("../")  # Add the parent directory to the Python path
import helper.utility as utility

# Model list
model_configs = ["Customized-cnn_ELU_"]
# optimizer list
optimizer_configs = ["SGD", "Adam_amsgrad"]
# Define different colors for the lines
colors = ["b", "g"]
plt.figure(figsize=(10, 6))

for i, model_name in enumerate(model_configs):
    for j, optimizer_name in enumerate(optimizer_configs):
        identifier = model_name + optimizer_name

        # load and plot the loss history
        record_save_path = "../../model_data/" + identifier
        data = utility.read_pickle_files(record_save_path + "/accuracy_history.pkl")
        color_index = (i * len(optimizer_configs) + j) % len(colors)
        plt.plot(
            range(1, len(data) + 1),
            data,
            label=identifier,
            color=colors[color_index],
        )

plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.title("Training Accuracy")
plt.legend()
plt.savefig("../../model_data/Round3/Customized-cnn_ELU_all_training_accuracy.png")
plt.show()

# %%
# Validation Loss

import matplotlib.pyplot as plt
import sys

sys.path.append("../")  # Add the parent directory to the Python path
import helper.utility as utility

# Model list
model_configs = ["Customized-cnn_ELU_"]
# optimizer list
optimizer_configs = ["SGD", "Adam_amsgrad"]
# Define different colors for the lines
colors = ["b", "g"]
plt.figure(figsize=(10, 6))

for i, model_name in enumerate(model_configs):
    for j, optimizer_name in enumerate(optimizer_configs):
        identifier = model_name + optimizer_name

        # load and plot the loss history
        record_save_path = "../../model_data/" + identifier
        data = utility.read_pickle_files(record_save_path + "/val_loss_history.pkl")
        color_index = (i * len(optimizer_configs) + j) % len(colors)
        plt.plot(
            range(1, len(data) + 1),
            data,
            label=identifier,
            color=colors[color_index],
        )

plt.xlabel("epoch")
plt.ylabel("validation loss")
plt.title("Validation Loss")
plt.legend()
plt.savefig("../../model_data/Round3/Customized-cnn_ELU_all_validation_loss.png")
plt.show()

# %%
# Validation Accuracy

import matplotlib.pyplot as plt
import sys

sys.path.append("../")  # Add the parent directory to the Python path
import helper.utility as utility

# Model list
model_configs = ["Customized-cnn_ELU_"]
# optimizer list
optimizer_configs = ["SGD", "Adam_amsgrad"]
# Define different colors for the lines
colors = ["b", "g"]
plt.figure(figsize=(10, 6))

for i, model_name in enumerate(model_configs):
    for j, optimizer_name in enumerate(optimizer_configs):
        identifier = model_name + optimizer_name

        # load and plot the loss history
        record_save_path = "../../model_data/" + identifier
        data = utility.read_pickle_files(record_save_path + "/val_accuracy_history.pkl")
        color_index = (i * len(optimizer_configs) + j) % len(colors)
        plt.plot(
            range(1, len(data) + 1),
            data,
            label=identifier,
            color=colors[color_index],
        )

plt.xlabel("epoch")
plt.ylabel("validation accuracy")
plt.title("Validation Accuracy")
plt.legend()
plt.savefig("../../model_data/Round3/Customized-cnn_ELU_all_validation_accuracy.png")
plt.show()

# %% [markdown]
# # The winner of Round 1 is `Customized-cnn_ELU_Adam_amsgrad` because it uses less epoch to train. (see the confusion matrix graph in report)
