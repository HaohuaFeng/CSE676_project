# %% [markdown]
# # comparison

# %%
# Training Loss

import matplotlib.pyplot as plt
import sys

sys.path.append("../../")  # Add the parent directory to the Python path
import helper.utility as utility

# Model list
model_configs = [
    "Alex_256_relu_Adam",
    "Alex_256_sigmoid_Adam",
    "Alex_256_tanh_Adam",
    "Alex_256_relu_SGD",
    "Alex_256_sigmoid_SGD",
    "Alex_256_tanh_SGD",
    "VGG16_4096_Adam",
    "VGG16_4096_Adam_amsgrad",
    "Customized-cnn_ELU_SGD",
    "Customized-cnn_ELU_Adam_amsgrad",
    "Alex_4096_relu_Adam",
    "Alex_4096_relu_SGD",
    "Alex_4096_tanh_Adam",
    "Alex_4096_tanh_SGD",
]

# Define different colors for the lines
colors = [
    "b",
    "g",
    "r",
    "c",
    "m",
    "y",
    "#5733FF",
    "#FF5733",
    "#FFD700",
    "#33FF57",
    "#FF69B4",
    "#A52A2A",
    "#8A2BE2",
    "#7FFF00",
]
plt.figure(figsize=(20, 12))

for i, model_name in enumerate(model_configs):
    identifier = model_name
    # load and plot the loss history
    record_save_path = "../../model_data/fer2013/" + identifier
    data = utility.read_pickle_files(record_save_path + "/loss_history.pkl")
    plt.plot(
        range(1, len(data) + 1),
        data,
        label=identifier,
        color=colors[i],
    )

plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("Training Loss")
plt.legend()
plt.savefig("../../model_data/fer2013/all_loss_history.png")
plt.show()

# %%
# Training Accuracy

import matplotlib.pyplot as plt
import sys

sys.path.append("../../")  # Add the parent directory to the Python path
import helper.utility as utility

# Model list
model_configs = [
    "Alex_256_relu_Adam",
    "Alex_256_sigmoid_Adam",
    "Alex_256_tanh_Adam",
    "Alex_256_relu_SGD",
    "Alex_256_sigmoid_SGD",
    "Alex_256_tanh_SGD",
    "VGG16_4096_Adam",
    "VGG16_4096_Adam_amsgrad",
    "Customized-cnn_ELU_SGD",
    "Customized-cnn_ELU_Adam_amsgrad",
    "Alex_4096_relu_Adam",
    "Alex_4096_relu_SGD",
    "Alex_4096_tanh_Adam",
    "Alex_4096_tanh_SGD",
]

# Define different colors for the lines
colors = [
    "b",
    "g",
    "r",
    "c",
    "m",
    "y",
    "#5733FF",
    "#FF5733",
    "#FFD700",
    "#33FF57",
    "#FF69B4",
    "#A52A2A",
    "#8A2BE2",
    "#7FFF00",
]
plt.figure(figsize=(20, 12))

for i, model_name in enumerate(model_configs):
    identifier = model_name

    # load and plot the loss history
    record_save_path = "../../model_data/fer2013/" + identifier
    data = utility.read_pickle_files(record_save_path + "/accuracy_history.pkl")
    plt.plot(
        range(1, len(data) + 1),
        data,
        label=identifier,
        color=colors[i],
    )

plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.title("Training Accuracy")
plt.legend()
plt.savefig("../../model_data/fer2013/all_training_accuracy.png")
plt.show()

# %%
# Validation Loss

import matplotlib.pyplot as plt
import sys

sys.path.append("../../")  # Add the parent directory to the Python path
import helper.utility as utility

# Model list
model_configs = [
    "Alex_256_relu_Adam",
    "Alex_256_sigmoid_Adam",
    "Alex_256_tanh_Adam",
    "Alex_256_relu_SGD",
    "Alex_256_sigmoid_SGD",
    "Alex_256_tanh_SGD",
    "VGG16_4096_Adam",
    "VGG16_4096_Adam_amsgrad",
    "Customized-cnn_ELU_SGD",
    "Customized-cnn_ELU_Adam_amsgrad",
    "Alex_4096_relu_Adam",
    "Alex_4096_relu_SGD",
    "Alex_4096_tanh_Adam",
    "Alex_4096_tanh_SGD",
]

# Define different colors for the lines
colors = [
    "b",
    "g",
    "r",
    "c",
    "m",
    "y",
    "#5733FF",
    "#FF5733",
    "#FFD700",
    "#33FF57",
    "#FF69B4",
    "#A52A2A",
    "#8A2BE2",
    "#7FFF00",
]
plt.figure(figsize=(20, 12))

for i, model_name in enumerate(model_configs):
    identifier = model_name
    # load and plot the loss history
    record_save_path = "../../model_data/fer2013/" + identifier
    data = utility.read_pickle_files(record_save_path + "/val_loss_history.pkl")
    plt.plot(
        range(1, len(data) + 1),
        data,
        label=identifier,
        color=colors[i],
    )

plt.xlabel("epoch")
plt.ylabel("validation loss")
plt.title("Validation Loss")
plt.legend()
plt.savefig("../../model_data/fer2013/all_validation_loss.png")
plt.show()

# %%
# Validation Accuracy

import matplotlib.pyplot as plt
import sys

sys.path.append("../../")  # Add the parent directory to the Python path
import helper.utility as utility

# Model list
model_configs = [
    "Alex_256_relu_Adam",
    "Alex_256_sigmoid_Adam",
    "Alex_256_tanh_Adam",
    "Alex_256_relu_SGD",
    "Alex_256_sigmoid_SGD",
    "Alex_256_tanh_SGD",
    "VGG16_4096_Adam",
    "VGG16_4096_Adam_amsgrad",
    "Customized-cnn_ELU_SGD",
    "Customized-cnn_ELU_Adam_amsgrad",
    "Alex_4096_relu_Adam",
    "Alex_4096_relu_SGD",
    "Alex_4096_tanh_Adam",
    "Alex_4096_tanh_SGD",
]

# Define different colors for the lines
colors = [
    "b",
    "g",
    "r",
    "c",
    "m",
    "y",
    "#5733FF",
    "#FF5733",
    "#FFD700",
    "#33FF57",
    "#FF69B4",
    "#A52A2A",
    "#8A2BE2",
    "#7FFF00",
]
plt.figure(figsize=(20, 12))

for i, model_name in enumerate(model_configs):
    identifier = model_name

    # load and plot the loss history
    record_save_path = "../../model_data/fer2013/" + identifier
    data = utility.read_pickle_files(record_save_path + "/val_accuracy_history.pkl")

    # Find the maximum accuracy and its corresponding epoch
    max_accuracy = max(data)
    max_epoch = data.index(max_accuracy) + 1  # Adding 1 because epochs start from 1

    plt.plot(
        range(1, len(data) + 1),
        data,
        label=identifier,
        color=colors[i],
    )

    # Annotating the maximum point
    plt.annotate(
        f"({max_epoch}, {max_accuracy:.3f})",
        xy=(max_epoch, max_accuracy),
        xytext=(5, 5),  # Slight offset for text
        textcoords="offset points",
        arrowprops=dict(arrowstyle="->", lw=1),
        ha="center",
    )

plt.xlabel("epoch")
plt.ylabel("validation accuracy")
plt.title("Validation Accuracy")
plt.legend()

plt.ylim(0.5, 0.66)

plt.savefig("../../model_data/fer2013/all_validation_accuracy.png")
plt.show()

# %% [markdown]
# # The winner of Round 1 is `Alex_256_ReLU_Adam` (see the confusion matrix graph in report)
