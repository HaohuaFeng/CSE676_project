# %% [markdown]
# # Round 4

# %% [markdown]
# # model: Alex_4096_relu_Adam v.s. VGG16_4096_Adam_amsgrad v.s. Customized-cnn_ELU_Adam_amsgrad
# ## we select the winner from them.

# %%
# Training Loss

import matplotlib.pyplot as plt
import sys

sys.path.append("../")  # Add the parent directory to the Python path
import helper.utility as utility

# Model list
model_configs = [
    "Alex_4096_relu_Adam",
    "VGG16_4096_Adam_amsgrad",
    "Customized-cnn_ELU_Adam_amsgrad",
]
# Define different colors for the lines
colors = ["b", "g", "r"]
plt.figure(figsize=(10, 6))

for i, model_name in enumerate(model_configs):
        identifier = model_name

        # load and plot the loss history
        record_save_path = "../../model_data/" + identifier
        data = utility.read_pickle_files(record_save_path + "/loss_history.pkl")
        plt.plot(
            range(1, len(data) + 1),
            data,
            label=identifier,
            color=colors[i],
        )

plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("Training Loss")
plt.legend()
plt.savefig("../../model_data/Round4/all_loss_history.png")
plt.show()

# %%
# Training Accuracy

import matplotlib.pyplot as plt
import sys

sys.path.append("../")  # Add the parent directory to the Python path
import helper.utility as utility

# Model list
model_configs = [
    "Alex_4096_relu_Adam",
    "VGG16_4096_Adam_amsgrad",
    "Customized-cnn_ELU_Adam_amsgrad",
]
# Define different colors for the lines
colors = ["b", "g", "r"]
plt.figure(figsize=(10, 6))

for i, model_name in enumerate(model_configs):
    identifier = model_name

    # load and plot the loss history
    record_save_path = "../../model_data/" + identifier
    data = utility.read_pickle_files(record_save_path + "/accuracy_history.pkl")
    plt.plot(
        range(1, len(data) + 1),
        data,
        label=identifier,
        color=colors[i],
    )

plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.title("Training Accuracy")
plt.legend()
plt.savefig("../../model_data/Round4/all_training_accuracy.png")
plt.show()

# %%
# Validation Loss

import matplotlib.pyplot as plt
import sys

sys.path.append("../")  # Add the parent directory to the Python path
import helper.utility as utility

# Model list
model_configs = [
    "Alex_4096_relu_Adam",
    "VGG16_4096_Adam_amsgrad",
    "Customized-cnn_ELU_Adam_amsgrad",
]
# Define different colors for the lines
colors = ["b", "g", "r"]
plt.figure(figsize=(10, 6))

for i, model_name in enumerate(model_configs):
    identifier = model_name

    # load and plot the loss history
    record_save_path = "../../model_data/" + identifier
    data = utility.read_pickle_files(record_save_path + "/val_loss_history.pkl")
    plt.plot(
        range(1, len(data) + 1),
        data,
        label=identifier,
        color=colors[i],
    )

plt.xlabel("epoch")
plt.ylabel("validation loss")
plt.title("Validation Loss")
plt.legend()
plt.savefig("../../model_data/Round4/all_validation_loss.png")
plt.show()

# %%
# Validation Accuracy

import matplotlib.pyplot as plt
import sys

sys.path.append("../")  # Add the parent directory to the Python path
import helper.utility as utility

# Model list
model_configs = [
    "Alex_4096_relu_Adam",
    "VGG16_4096_Adam_amsgrad",
    "Customized-cnn_ELU_Adam_amsgrad",
]
# Define different colors for the lines
colors = ["b", "g", "r"]
plt.figure(figsize=(10, 6))

for i, model_name in enumerate(model_configs):
    identifier = model_name

    # load and plot the loss history
    record_save_path = "../../model_data/" + identifier
    data = utility.read_pickle_files(record_save_path + "/val_accuracy_history.pkl")
    plt.plot(
        range(1, len(data) + 1),
        data,
        label=identifier,
        color=colors[i],
    )

plt.xlabel("epoch")
plt.ylabel("validation accuracy")
plt.title("Validation Accuracy")
plt.legend()
plt.savefig("../../model_data/Round4/all_validation_accuracy.png")
plt.show()

# %% [markdown]
# # The winner of Round 1 is `Customized-cnn_ELU_Adam_amsgrad` because it is more stable. (see the confusion matrix graph in report)
# # We then do further optimization works on `Customized-cnn_ELU_Adam_amsgrad`.
